# %% [markdown]
# # Projekt:

# %% [markdown]
# # Animacja DLA UCZENIA NADZOROWANEGO

# %% [markdown]
# ### Jako podstawę do animacji wziąłem pracę domową $№2.1$

# %% [markdown]
# Poniżej zaimportowałem niezbędne biblioteki :

# %%
import math  as m
import numpy as np

# liczby losowe
import random

# grafika do wykresów
import matplotlib.pyplot as plt
import matplotlib as mpl

                     # Nowe biblioteki są :
# wyświetlanie inportowanej grafiki;   Wyświetlanie filmu z Youtube
from IPython.display import display, Image, HTML, Video, YouTubeVideo

# Animacja za pomocą matplotlib
from matplotlib.animation import FuncAnimation

# %% [markdown]
# Skorzystamy próbkę dla 100 punktów :

# %%
npo_zad=100  # próbka dla 100 punktów
probka_zad=np.array([[0.21411625, 0.96426023, 1.        ],
       [0.22324566, 0.75905896, 1.        ],
       [0.4117554 , 0.34329326, 0.        ],
       [0.2711907 , 0.12370197, 0.        ],
       [0.24360769, 0.69161061, 1.        ],
       [0.82557679, 0.28831672, 0.        ],
       [0.11778537, 0.18727798, 0.        ],
       [0.37364829, 0.64794825, 0.        ],
       [0.05767847, 0.22841702, 0.        ],
       [0.51382561, 0.4459305 , 0.        ],
       [0.08377459, 0.8323045 , 1.        ],
       [0.30638091, 0.94363382, 1.        ],
       [0.98635476, 0.18477572, 0.        ],
       [0.1671712 , 0.78414165, 1.        ],
       [0.54413143, 0.49782506, 0.        ],
       [0.39776042, 0.61528028, 0.        ],
       [0.95335917, 0.65703114, 0.        ],
       [0.87981245, 0.50926651, 0.        ],
       [0.67312829, 0.88043416, 1.        ],
       [0.55206559, 0.52392534, 0.        ],
       [0.42397127, 0.50171963, 0.        ],
       [0.52890739, 0.81960211, 1.        ],
       [0.26193735, 0.88260791, 1.        ],
       [0.6321066 , 0.66328535, 0.        ],
       [0.49597402, 0.78939291, 1.        ],
       [0.22327814, 0.04039445, 0.        ],
       [0.13685725, 0.10346859, 0.        ],
       [0.86794371, 0.88305935, 0.        ],
       [0.77430846, 0.60564586, 0.        ],
       [0.61566571, 0.39960006, 0.        ],
       [0.5915284 , 0.07831388, 0.        ],
       [0.81632253, 0.64406071, 0.        ],
       [0.50511946, 0.56920466, 0.        ],
       [0.16550553, 0.45745027, 0.        ],
       [0.99713275, 0.53636606, 0.        ],
       [0.01443198, 0.33898612, 0.        ],
       [0.32373937, 0.7176002 , 1.        ],
       [0.09929523, 0.10931214, 0.        ],
       [0.33271418, 0.95198756, 1.        ],
       [0.75342841, 0.18732687, 0.        ],
       [0.20004117, 0.74801575, 1.        ],
       [0.17073802, 0.60582168, 1.        ],
       [0.93276028, 0.96203644, 0.        ],
       [0.89727244, 0.21999518, 0.        ],
       [0.26505477, 0.32804044, 0.        ],
       [0.98775909, 0.59690451, 0.        ],
       [0.73123641, 0.4223595 , 0.        ],
       [0.13765982, 0.45835786, 0.        ],
       [0.58890224, 0.83358183, 1.        ],
       [0.69194158, 0.4892326 , 0.        ],
       [0.73285548, 0.79854423, 0.        ],
       [0.79537148, 0.00726942, 0.        ],
       [0.13863056, 0.64524872, 1.        ],
       [0.6180183 , 0.29632804, 0.        ],
       [0.15508292, 0.27094423, 0.        ],
       [0.23975514, 0.44338425, 0.        ],
       [0.45848827, 0.74047281, 1.        ],
       [0.92297693, 0.25545246, 0.        ],
       [0.74555793, 0.96315318, 1.        ],
       [0.41847552, 0.15568741, 0.        ],
       [0.26959336, 0.32159808, 0.        ],
       [0.29042272, 0.36942159, 0.        ],
       [0.91177321, 0.87743833, 0.        ],
       [0.25887314, 0.16953158, 0.        ],
       [0.06844735, 0.63782016, 1.        ],
       [0.77424525, 0.9895361 , 1.        ],
       [0.05633817, 0.35357194, 0.        ],
       [0.67019683, 0.97380585, 1.        ],
       [0.53481062, 0.26041486, 0.        ],
       [0.40106496, 0.90400998, 1.        ],
       [0.30992124, 0.81593767, 1.        ],
       [0.91972018, 0.01540877, 0.        ],
       [0.78343784, 0.56966247, 0.        ],
       [0.05488208, 0.17363594, 0.        ],
       [0.7586225 , 0.04681934, 0.        ],
       [0.47529445, 0.09100629, 0.        ],
       [0.04372663, 0.02394718, 0.        ],
       [0.66592134, 0.39809222, 0.        ],
       [0.13766527, 0.16501437, 0.        ],
       [0.41401435, 0.49161511, 0.        ],
       [0.53677115, 0.55888038, 0.        ],
       [0.67360044, 0.14661837, 0.        ],
       [0.30318252, 0.97307937, 1.        ],
       [0.16660573, 0.76354061, 1.        ],
       [0.71190111, 0.35465919, 0.        ],
       [0.39960201, 0.61395272, 0.        ],
       [0.50833303, 0.4420134 , 0.        ],
       [0.5678389 , 0.47170079, 0.        ],
       [0.89698516, 0.31700293, 0.        ],
       [0.28335266, 0.63933601, 0.        ],
       [0.21456851, 0.42848696, 0.        ],
       [0.41184576, 0.06591686, 0.        ],
       [0.60086703, 0.0054513 , 0.        ],
       [0.49675323, 0.76765488, 1.        ],
       [0.81782645, 0.54481398, 0.        ],
       [0.87868515, 0.33396848, 0.        ],
       [0.89431149, 0.36767782, 0.        ],
       [0.74675681, 0.33050737, 0.        ],
       [0.20001737, 0.18582118, 0.        ]])

# %% [markdown]
# Wyświetlanie pozycji punktów i linii na wykresie :

# %%
w0=random.random()-0.5
w1=random.random()-0.5
w2=random.random()-0.5

# linia do grafiki
def l2_zad(w0,w1,w2):
    return [-.1,1.1],[-(w0-w1*0.1)/w2,-(w0+w1*1.1)/w2]

lin_zad=l2_zad(0,1,-1)
lin_zad

plt.figure(figsize=(5,5))
plt.title("Podział na 2 klasy losowych punktów",fontsize=16) 
plt.xlim(-.1,1.1)
plt.ylim(-.1,1.1)
plt.scatter(probka_zad[:,0],probka_zad[:,1],c=probka_zad[:,2],
            s=35,cmap = plt.cm.get_cmap("autumn"),
            norm=mpl.colors.Normalize(vmin=0, vmax=.9))
            
plt.plot(lin_zad[0],lin_zad[1])

plt.xlabel('$x_1$',fontsize=18)
plt.ylabel('$x_2$',fontsize=18);

# %% [markdown]
# Powyżej widzimy, że linia nie rozdziela punktów w dokładny sposób :

# %% [markdown]
# ### Aby poprawnie wyświetlić linię na wykresie, używamy algorytmu  UCZENIA

# %% [markdown]
# ### Stworzyliśmy również 2 puste listy (lin i lin_zad), w których umieszczamy potrzebne dane dla animacji

# %%
lin = []
lin_zad=[]
# funkcja aktywacji = dobrze znana funkcja schodkowa
def f(s):
     if s > 0:
        return 1
     else:
        return 0

# algorytm uczenia

for u in range(20): # powtarzamy całość wiele (20) razy
    eps=1/(u*u+2) # istotne, by parametr uaktualniania się w jakiś sposób zmniejszał w kolejnych iteracjach                  
    for ind_zad in range(npo_zad-1): # pętla po punktach z próbki, ind_zad jest numerem punktu
        for k in range(10): # dla każdego punktu powtarzamy 10 razy
            
            y=f(w0+w1*probka_zad[ind_zad,0]+w2*probka_zad[ind_zad,1]) # odpowiedż dla danego punktu
            
            # uaktualnienie wag
            w0=w0+eps*(probka_zad[ind_zad,2]-y)*1
            w1=w1+eps*(probka_zad[ind_zad,2]-y)*probka_zad[ind_zad,0]
            w2=w2+eps*(probka_zad[ind_zad,2]-y)*probka_zad[ind_zad,1]
    print(w0,w1,w2)
    lin=l2_zad(w0,w1,w2) #  'lin'  przyjmuje wartość wyniku funkcji  'l2_zad(w0,w1,w2)'
    lin_zad.append(lin)  #  polecenie  '.append'  dodaje wartość zmiennej  'lin'  na końcu listy  'lin_zad'
# Out:
# -0.2552944184952458 -0.7694456271809289 1.5523572118299809
# -0.5886277518285792 -0.8971266471809288 1.4551654884966476
# -0.5886277518285792 -0.8689562255142622 1.4938905168299808
# -0.5886277518285792 -0.8476981255142622 1.5221929950117992
# -0.6441833073841348 -0.8566007766253733 1.4933246961229103
# -0.6812203444211717 -0.862535877366114 1.4740791635303179
# -0.6812203444211717 -0.8569200728924298 1.477455975898739
# -0.6812203444211717 -0.852735747990469 1.4799720321732488
# -0.6963718595726869 -0.8537956281419841 1.4722293482338547
# -0.6963718595726869 -0.8512245369371647 1.4737753587157825
# -0.6963718595726869 -0.8491323744861844 1.4750333868530372
# -0.7045019408734999 -0.851436054648786 1.4698355331131998
# -0.7045019408734999 -0.8502364956761833 1.470528250921419
# -0.7045019408734998 -0.8492123108223821 1.4711196941962728
# -0.7045019408734998 -0.8483277875395538 1.4716304861154645
# -0.7045019408734998 -0.8475562650285406 1.4720760226793412
# ...

# %% [markdown]
# Końcowe współrzędne dla pozycji linii :

# %%
l2_zad(w0,w1,w2)
# ([x1, x2] , [y1, y2])
# Out:
# ([-0.1, 1.1], [0.42077812414371274, 1.1091886357019805])

# %% [markdown]
# Wyświetlanie wykresu z wyszkoloną siecią neuronową :

# %%
# odpowiadająca im linia podziału
lin_Z=l2_zad(w0,w1,w2)

plt.figure(figsize=(5,5))
plt.title("Podział na 2 klasy losowych punktów",fontsize=16) 
plt.xlim(-.1,1.1)
plt.ylim(-.1,1.1)
plt.scatter(probka_zad[:,0],probka_zad[:,1],c=probka_zad[:,2],   
            # s=20,cmap=mpl.cm.cool,
            s=35,cmap = plt.cm.get_cmap("autumn"),
            norm=mpl.colors.Normalize(vmin=0, vmax=.9))   
            
plt.plot(lin_Z[0],lin_Z[1])

plt.xlabel('$x_1$',fontsize=18)
plt.ylabel('$x_2$',fontsize=18);

# %% [markdown]
# # Powyższy kod narysował punkty próbki i aktualną linię rozdzielającą.  Jednak nie widzimy całego procesu uczenia. W tym celu utworzymy klip animacyjny, w którym wszystkie etapy ruchu linii będą wyraźnie widoczne.

# %% [markdown]
# ### Dzielimy jedną listę $lin$_$zad$ na 2 listy: $linX$ i $linY$ :

# %%
linX = []
linY = []
i=0
for _ in lin_zad:
    linX.append(lin_zad[i][0]) #  polecenie  '.append'  dodaje wartość zmiennej  'lin_zad[i][0]'  na końcu listy  'linX'
    linY.append(lin_zad[i][1]) #  polecenie  '.append'  dodaje wartość zmiennej  'lin_zad[i][1]'  na końcu listy  'linY'
    i+=1
linY        # Sprawdźmy listę linY
# Out:
# [[0.11488970091291485, 0.7096849874492209],
#  [0.3428579711754452, 1.0826720920623527],
#  [0.3358560240022294, 1.0338639829989926],
#  [0.33100792141882596, 0.9992791287825346],
#  [0.37401325456659246, 1.0623571456300824],
#  [0.4036192705279518, 1.1057817313014155],
#  [0.40307687460512515, 1.0990733064753857],
#  [0.4026743456408519, 1.0940947747728365],
#  [0.4150116267492285, 1.110932241970952],
#  [0.41475072999700613, 1.1078478416319064],
#  [0.414538835238575, 1.1053427576890056],
#  [0.4213793458216262, 1.1165069587828342],
#  [0.42126242111820866, 1.1150837021253024],
#  [0.42116267781308, 1.113869584672624],
#  [0.4210766003871199, 1.1128218140477675],
#  [0.4210015684126414, 1.111908493303024],
#  [0.42093558945814585, 1.111105369724361],
#  [0.42087712202642197, 1.1103936795595162],
#  [0.4208249550771052, 1.10975868151592],
#  [0.42077812414371274, 1.1091886357019805]]

# %% [markdown]
# ### Moim źródłem inspiracji był film z YouTube https://www.youtube.com/watch?v=GtZxk8Wa3Jw

# %% [markdown]
# ### Aby uruchomić kod z filmu, musiałem zainstalować FFmpeg.

# %% [markdown]
# $FFmpeg$ – wieloplatformowy projekt, którego celem jest dostarczenie kompletnej platformy do nagrywania, konwertowania i przesyłania strumieniowego treści audiowizualnych.

# %% [markdown]
# ### Znalazłem odpowiedź, jak zainstalować FFmpeg na stronie: https://stackoverflow.com/questions/13316397/matplotlib-animation-no-moviewriters-available

# %% [markdown]
# ### Tam osoba pod pseudonimem JPH doradziła 2 linki do stron:
# - http://www.wikihow.com/Install-FFmpeg-on-Windows   Instrukcje dotyczące instalowania FFmpeg
# - http://ffmpeg.zeranoe.com/builds/       Link do pobrania FFmpeg

# %% [markdown]
# Udało mi się uruchomić kod wykresu funkcji $sinus$ z tego filmu na YouTube :

# %%
x = np.linspace(0, 2*np.pi, 100)

fig = plt.figure()

lines = plt.plot([])
line = lines[0]
# other setup
plt.xlim(0, 2*np.pi)
plt.ylim(-1.1, 1.1)

def animate(frame):
    #update plot
    y = np.sin(x + 2*np.pi * frame/100)
    line.set_data((x, y))
    
anim = FuncAnimation(fig, animate, frames=100, interval=20)
video = anim.to_html5_video()
display(HTML(video))     
plt.close()
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# # Następnie lepiej zrozumiałem, jak działa biblioteka $matplotlib$. Byłem bardziej zainteresowany w $ matplotlib.animation.FuncAnimation$

# %% [markdown]
# # Aby uzyskać szczegółowe informacje, znalazłem dokumentację

# %% [markdown]
# ### Link do dokumentacji:       https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.animation.FuncAnimation.html

# %% [markdown]
# Funkcja:

# %% [markdown]
# $class$ matplotlib.animation.FuncAnimation(fig, func, frames=None, init_func=None, fargs=None, save_count=None, cache_frame_data=True, **kwargs)

# %% [markdown]
# Najważniejsze parametry tej funkcji opisano poniżej :

# %% [markdown]
# - $FIG$ - Obiekt $figure()$ używany do rysowania, zmiany rozmiaru i innych potrzebnych zdarzeń.
# - $FUNC$ - Funkcja wywoływania w każdej ramce.
# - $FRAMES$ - Źródło danych do przekazania $func$ i każdej klatki animacji.
# - $INIT$_$FUNC$ - Funkcja używana do rysowania wyraźnej ramki.
# - $FARGS$ - Dodatkowe argumenty przekazywane do każdego wywołania func.
# - $SAVE$_$COUNT$ - Powrót do liczby wartości z ramek do pamięci podręcznej.
# - $CACHE$_$FRAME$_$DATA$ - Kontroluje, czy dane ramki są buforowane.
# - **$KWARGS$ = słownik - którego klucze stają się oddzielnymi argumentami słów kluczowych, a wartości stają się wartościami tych argumentów

# %% [markdown]
# # Na podstawie powyższych źródeł stworzyłem animację dla uczenia nadzorowanego sieci neuronowej.

# %%
fig = plt.figure() # Obiekt figure() używany do rysowania, zmiany rozmiaru i innych potrzebnych zdarzeń.

lines = plt.plot([])
line = lines[0]  # Pozycja początkowa linii na wykresie
plt.xlim(-0.1, 1.1)    #  rozmiary wykresu zgodnie osi X
plt.ylim(-0.1, 1.1)    #  rozmiary wykresu zgodnie osi Y
plt.scatter(probka_zad[:,0],probka_zad[:,1],c=probka_zad[:,2],   # próbka dla 100 punktów 
            s=35,cmap = plt.cm.get_cmap("autumn"),               # stylizacja punktów
            norm=mpl.colors.Normalize(vmin=0, vmax=.9))

def animacja(i):                          # Funkcja wywoływania w każdej ramce.
    line.set_data((linX[i], linY[i]))     # Funkcja animacja() dla ruchu linii
    
anim = FuncAnimation(fig, animacja, repeat=True, frames=np.arange(0, 20), interval=1000)
# Zmienna 'anim' przyjmuje wartość funkcji FuncAnimation().
video = anim.to_html5_video()  
# Zmienna 'video' przyjmuje wynik konwersji animacji na znacznik <video> HTML5.
display(HTML(video))       # Wyświetlanie filmu w odtwarzaczu
plt.close()
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### Odstęp między każdą pozycją linii wynosi jedną sekundę.

# %% [markdown]
# # Bardziej szczegółowe wyjaśnienie ostatniego kawałka kodu :

# %% [markdown]
# - Zmienna $anim$ przyjmuje wartość funkcji $FuncAnimation()$.
# - Następnie zmienna $video$ przyjmuje wynik konwersji animacji na znacznik $<video>$ HTML5 () ze standardowymi ustawieniami.
# - Element HTML $<video>$ służy do wyświetlania wideo na stronie internetowej w odtwarzaczu.

# %% [markdown]
# Przykład konwersji kodu z Python  na HTML:

# %% [raw]
# <video width="320" height="240" controls>
#   <source src="movie.mp4" type="video/mp4">
#   <source src="movie.ogg" type="video/ogg">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ## Jak to działa

# %% [markdown]
# Atrybut $controls$ dodaje elementy sterujące wideo, takie jak odtwarzanie, pauza i głośność.

# %% [markdown]
# Dobrym pomysłem jest zawsze dołączanie atrybutów szerokości ($width$) i wysokości ($height$). Jeśli wysokość i szerokość nie zostaną ustawione, strona może migotać podczas ładowania wideo.

# %% [markdown]
# Element $<source>$ pozwala określić alternatywne pliki wideo, z których przeglądarka może wybierać. Przeglądarka użyje pierwszego rozpoznanego formatu.

# %% [markdown]
# Tekst między tagami $<video>$ i $</video>$ będzie wyświetlany tylko w przeglądarkach, które $nie$ obsługują elementu $<video>$.

# %% [markdown]
# - W naszym przypadku, element HTML  <𝑣𝑖𝑑𝑒𝑜>  przyjmuje wynik konwersji z Python na HTML ze standardowymi ustawieniami.

# %% [markdown]
# # Wniosek:
# ### Widać wyraźnie, że najbardziej znaczące zmiany zachodzą w ciągu pierwszych 5 sekund. Następnie obserwujemy spadek wydajności.  Biblioteka $matplotlib.animation$ pomogła nam zauważyć nierównomierny rozkład wydajności w czasie.

# %% [markdown]
# # Również użyteczne źródła informacji dla mnie były:

# %% [markdown]
# - https://matplotlib.org/3.2.1/api/animation_api.html
# - https://matplotlib.org/2.0.2/api/lines_api.html
# - https://www.youtube.com/watch?reload=9&v=zgS9LdLM36E
# - https://www.youtube.com/watch?v=dOKHY_PUvqU
# - https://www.youtube.com/watch?v=ZmYPzESC5YY
# - https://www.it-swarm.dev/pl/python/uzycie-args-i-kwargs/969097115/
# - https://www.w3schools.com/html/html5_video.asp

# %% [markdown]
# ### Jeśli nie ma możliwości odtworzyć wideo, sugeruję obejrzenie już pobranej wersji. Ten film został pobrany tutaj i przesłany na YouTube

# %%
def display_yotube_video(url, **kwargs):
    """
    Displays a Youtube video in a Jupyter notebook.
    
    Args:
        url (string): a link to a Youtube video.
        **kwargs: further arguments for IPython.display.YouTubeVideo
    
    Returns:
        YouTubeVideo: a video that is displayed in your notebook.
    """
    id_ = url.split("=")[-1]
    return YouTubeVideo(id_, **kwargs)

display_yotube_video("https://www.youtube.com/watch?v=5rF6Q5-eDb8&feature=youtu.be", width=800, height=600)

# %% [markdown]
# # LUB

# %%
Video("animacja.mp4")
# Out:
# <video src="animacja.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# # Student:

# %% [markdown]
# Stepan Garciu (135 843). Inżynieria danych (2 rok)
